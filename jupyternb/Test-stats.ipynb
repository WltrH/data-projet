# %% [markdown]
# # Tests sur les données JSON

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Lecture des données json TOP10
#df = pd.read_json('json/top10.json')
#df.head()

# %%
# Lecture des données json TOP10
df = pd.read_json('json/top10.json')
df.head()
# Out:
#             id symbol      name  \
# 0      bitcoin    btc   Bitcoin
# 1     ethereum    eth  Ethereum
# 2       tether   usdt    Tether
# 3  binancecoin    bnb       BNB
# 4     usd-coin   usdc  USD Coin
#
#                                                image  current_price  \
# 0  https://assets.coingecko.com/coins/images/1/la...   24570.000000
# 1  https://assets.coingecko.com/coins/images/279/...    1681.070000
# 2  https://assets.coingecko.com/coins/images/325/...       0.999887
# 3  https://assets.coingecko.com/coins/images/825/...     321.160000
# 4  https://assets.coingecko.com/coins/images/6319...       0.998350
#
#      market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  474731106585                1             5.167476e+11   48262800628
# 1  202891661316                2             2.028917e+11   13219167766
# 2   69777838935                3             6.977784e+10   61745635226
# ...

# %%
#Prix actuels et variations récentes des prix des crypto-monnaies classées par capitalisation boursière
plt.figure(figsize=(20,10))
sns.barplot(x='market_cap', y='name', data=df, palette='rocket')
plt.title('Prix actuels et variations récentes des prix des crypto-monnaies classées par capitalisation boursière', fontsize=20)
plt.xlabel('Prix actuel en USD', fontsize=15)
plt.ylabel('Nom de la crypto-monnaie', fontsize=15)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Capitalisation boursière totale des crypto-monnaies avec comparaison avec le marché des 10 crypto-monnaies les plus chères
plt.figure(figsize=(20,10))
sns.barplot(x='market_cap', y='name', data=df, palette='rocket')
plt.title('Capitalisation boursière totale des crypto-monnaies avec comparaison avec le marché des 10 crypto-monnaies les plus chères', fontsize=20)
plt.xlabel('Capitalisation boursière totale en USD', fontsize=15)
plt.ylabel('Nom de la crypto-monnaie', fontsize=15)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#selection des colonnes à afficher
df = df[['name', 'current_price', 'market_cap', 'fully_diluted_valuation', 'total_volume', 'high_24h', 'low_24h']]
df.head()
# Out:
#        name  current_price    market_cap  fully_diluted_valuation  \
# 0   Bitcoin   24570.000000  474731106585             5.167476e+11
# 1  Ethereum    1681.070000  202891661316             2.028917e+11
# 2    Tether       0.999887   69777838935             6.977784e+10
# 3       BNB     321.160000   50815500069             6.436408e+10
# 4  USD Coin       0.998350   41410603134             4.140115e+10
#
#    total_volume   high_24h       low_24h
# 0   48262800628  24743.000  22103.000000
# 1   13219167766   1700.570   1547.090000
# 2   61745635226      1.005      0.987296
# 3    1482780214    324.270    297.400000
# 4    4417479027      1.005      0.985272

# %%
#Affichage des données en corelations
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot=True, cmap='rocket')
plt.title('Affichage des données en corelations', fontsize=20) 
plt.show()

# %%
# recherche de corelations entre les données
sns.pairplot(df, hue='name', palette='rocket')

# %%
#prise des données historique du bitcoin dans le fichier json
df = pd.read_json('json/histo-bitcoin.json')
df.head()
# Out:
#                                 prices                          market_caps  \
# 0  [1673964138710, 19564.633016775027]   [1673964138710, 377119226398.2988]
# 1  [1673967783570, 19484.699132360656]  [1673967783570, 374226379563.83026]
# 2  [1673971242421, 19562.381416708617]   [1673971242421, 376338181676.2104]
# 3  [1673975022651, 19673.327218929524]   [1673975022651, 379742529343.4641]
# 4  [1673978489727, 19672.633698443366]  [1673978489727, 378910597390.90955]
#
#                          total_volumes
# 0   [1673964138710, 28824136730.45368]
# 1   [1673967783570, 31639660669.04655]
# 2  [1673971242421, 31945066806.599655]
# 3   [1673975022651, 32294538297.73367]
# 4  [1673978489727, 31944199124.116844]

# %%
#changer la mise en forme de la colonne prices pour mettre en date
df[['date', 'price']['date','market_caps']['date','total_volumes']] = df['prices'].apply(pd.Series)
#df2 = df[['date', 'market_caps']] = df['market_caps'].apply(pd.Series)
#df3 = df[['date', 'total_volumes']]= df['market_caps'].apply(pd.Series)

#mise en forme de la date
#
#suppr
#mise en forme de la date
df['date'] = pd.to_datetime(df['date'], unit='ms')
df1 = df[['date', 'price']]
#df2['date'] = pd.to_datetime(df2['date'], unit='ms')
#df3['date'] = pd.to_datetime(df3['date'], unit='ms')
#création d'un data frame avec les colonnes date et total_volumes
#df3 = df[['date', 'total_volumes']].apply(pd.Series)
#mise en forme de la date

df1.head()
#mettre la date, le price et le market_cap dans un dataframe
#df4 = df[['date', 'price', 'market_caps', 'total_volumes']]
#df4.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/dv/c6lkk7cd12xc73lprmyn2fcw0000gn/T/ipykernel_88458/1246145205.py in <module>
#       1 #changer la mise en forme de la colonne prices pour mettre en date
# ----> 2 df[['date', 'price']['date','market_caps']['date','total_volumes']] = df['prices'].apply(pd.Series)
#       3 #df2 = df[['date', 'market_caps']] = df['market_caps'].apply(pd.Series)
#       4 #df3 = df[['date', 'total_volumes']]= df['market_caps'].apply(pd.Series)
#       5
#
# TypeError: list indices must be integers or slices, not tuple

# %%
df = pd.read_json('json/histo-bitcoin.json')

df[['date', 'price']] = df['prices'].apply(lambda x: pd.Series([x[0], x[1]])).add_prefix('price_')
df[['date', 'market_cap']] = df['market_caps'].apply(lambda x: pd.Series([x[0], x[1]])).add_prefix('market_cap_')
df[['date', 'total_volume']] = df['total_volumes'].apply(lambda x: pd.Series([x[0], x[1]])).add_prefix('total_volume_')
df.head()
#df = df.drop(['prices', 'market_caps', 'total_volumes'], axis=1)
#mettre la date au format jour, mois et année
#df['date'] = pd.to_datetime(df['date'], unit='ms')
#df['date'] = pd.to_datetime(df['date'], unit='H')
#df.head()

#mise de la date en index
#df = df.set_index('date')
#df.head()
# Out:
#                                 prices                          market_caps  \
# 0  [1673964138710, 19564.633016775027]   [1673964138710, 377119226398.2988]
# 1  [1673967783570, 19484.699132360656]  [1673967783570, 374226379563.83026]
# 2  [1673971242421, 19562.381416708617]   [1673971242421, 376338181676.2104]
# 3  [1673975022651, 19673.327218929524]   [1673975022651, 379742529343.4641]
# 4  [1673978489727, 19672.633698443366]  [1673978489727, 378910597390.90955]
#
#                          total_volumes          date         price  \
# 0   [1673964138710, 28824136730.45368]  1.673964e+12  19564.633017
# 1   [1673967783570, 31639660669.04655]  1.673968e+12  19484.699132
# 2  [1673971242421, 31945066806.599655]  1.673971e+12  19562.381417
# 3   [1673975022651, 32294538297.73367]  1.673975e+12  19673.327219
# 4  [1673978489727, 31944199124.116844]  1.673978e+12  19672.633698
#
#      market_cap  total_volume
# 0  3.771192e+11  2.882414e+10
# 1  3.742264e+11  3.163966e+10
# ...

# %%
df = df.drop(['prices', 'market_caps', 'total_volumes'], axis=1)
#mettre la date au format jour, mois et année
df['date'] = pd.to_datetime(df['date'], unit='ms')
#df['date'] = pd.to_datetime(df['date'].dt.date, unit='ms')
df.head()
# Out:
#                            date         price    market_cap  total_volume
# 0 2023-01-17 14:02:18.710000128  19564.633017  3.771192e+11  2.882414e+10
# 1 2023-01-17 15:03:03.569999872  19484.699132  3.742264e+11  3.163966e+10
# 2 2023-01-17 16:00:42.420999936  19562.381417  3.763382e+11  3.194507e+10
# 3 2023-01-17 17:03:42.651000064  19673.327219  3.797425e+11  3.229454e+10
# 4 2023-01-17 18:01:29.727000064  19672.633698  3.789106e+11  3.194420e+10

# %%
#mettre la date juste au format jour, mois et année
df['date'] = df['date'].dt.date
df.head()
# Out:
#          date         price    market_cap  total_volume
# 0  2023-01-17  19564.633017  3.771192e+11  2.882414e+10
# 1  2023-01-17  19484.699132  3.742264e+11  3.163966e+10
# 2  2023-01-17  19562.381417  3.763382e+11  3.194507e+10
# 3  2023-01-17  19673.327219  3.797425e+11  3.229454e+10
# 4  2023-01-17  19672.633698  3.789106e+11  3.194420e+10

# %%
sns.pairplot(df, hue ='price', palette='rocket')

# %%
import json

json_data = open('WorldMap.geojson').read()

data = json.loads(json_data)
#print(data)
for i in data['features']:
   print(i['properties']['name'])
# Out:
# Afghanistan
# Angola
# Albania
# United Arab Emirates
# Argentina
# Armenia
# Antarctica
# French Southern and Antarctic Lands
# Bangladesh
# Bulgaria
# Bosnia and Herzegovina
# Australia
# Austria
# Azerbaijan
# Burundi
# Belgium
# Benin
# Burkina Faso
# The Bahamas
# Belarus
# Belize
# Bermuda
# Bolivia
# Brazil
# Brunei
# Bhutan
# Botswana
# Central African Republic
# Canada
# Switzerland
# Chile
# Republic of the Congo
# Colombia
# Costa Rica
# China
# Ivory Coast
# Cameroon
# Democratic Republic of the Congo
# Cuba
# Northern Cyprus
# Cyprus
# Czech Republic
# Germany
# Djibouti
# Denmark
# Dominican Republic
# Algeria
# Ecuador
# Egypt
# Eritrea
# Spain
# Estonia
# Ethiopia
# Finland
# Fiji
# Falkland Islands
# France
# Gabon
# United Kingdom
# Georgia
# Ghana
# Macedonia
# Guinea
# Gambia
# Guinea Bissau
# Equatorial Guinea
# Greece
# Greenland
# Guatemala
# French Guiana
# Guyana
# Slovakia
# Honduras
# Croatia
# Haiti
# Hungary
# Indonesia
# Slovenia
# India
# Ireland
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /var/folders/dv/c6lkk7cd12xc73lprmyn2fcw0000gn/T/ipykernel_61781/1811987643.py in <module>
#       1 # ouverture du fichier csv
#       2
# ----> 3 df = pd.read_csv('capitals.csv')
#       4 df.head()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
